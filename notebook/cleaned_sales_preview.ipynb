# %% [markdown]
# # Cleaned Sales Preview
#
# Quick validation notebook for the `data/processed/synosales_cleaned.parquet` output. Once the structure is confirmed, lift the aggregation logic into a production module under `src/` as part of the export-to-module plan.

# %%
from pathlib import Path

import pandas as pd

# %%
project_root = Path().resolve()
if project_root.name == "notebook":
    project_root = project_root.parent

data_path = project_root / "data/processed/synosales_cleaned.parquet"
df_cleaned = pd.read_parquet(data_path)
df_cleaned.head()
# Out:
#           PI Customer ItemCode                            Product Currency  \
# 0  2364503.0       C2     None                C2 Storage Advanced      EUR
# 1  2364504.0       C2     None                   C2 Storage Basic      EUR
# 2  2364505.0       C2     None                   C2 Storage Basic      USD
# 3  2364506.0       C2     None  Active Insight Premium Early Bird      EUR
# 4  2364507.0       C2     None                C2 Storage Advanced      EUR
#
#      Price  Quantity  Discount  T/T Discount    Total  ... source_sheet  \
# 0   104.69         1       0.0           0.0   104.69  ...      2023-C2
# 1    35.33         1       0.0           0.0    35.33  ...      2023-C2
# 2     1.96         1       0.0           0.0     1.96  ...      2023-C2
# 3    12.53         1       0.0           0.0    12.53  ...      2023-C2
# 4  1246.98         1       0.0           0.0  1246.98  ...      2023-C2
#
#         Type                      sub_cat exchange_rate_to_usd  \
# 0  C2-HYBRID  C2-STORAGE-UNKNOWN-ADVANCED                 1.05
# 1  C2-HYBRID     C2-STORAGE-UNKNOWN-BASIC                 1.05
# 2  C2-HYBRID     C2-STORAGE-UNKNOWN-BASIC                 1.00
# 3  C2-HYBRID                        Other                 1.05
# 4  C2-HYBRID  C2-STORAGE-UNKNOWN-ADVANCED                 1.05
#
#   usd_adjusted_price usd_adjusted_total  Year Capacity  Unit total_cap
# 0           109.9245           109.9245  2023      NaN  None         0
# 1            37.0965            37.0965  2023      NaN  None         0
# 2             1.9600             1.9600  2023      NaN  None         0
# 3            13.1565            13.1565  2023      NaN  None         0
# 4          1309.3290          1309.3290  2023      NaN  None         0
#
# [5 rows x 27 columns]

# %%
df_cleaned.columns.tolist()
# Out:
# ['PI',
#  'Customer',
#  'ItemCode',
#  'Product',
#  'Currency',
#  'Price',
#  'Quantity',
#  'Discount',
#  'T/T Discount',
#  'Total',
#  'ShipDate',
#  'InvDate',
#  'DeliveryFrom',
#  'Destination',
#  'Comments',
#  'Country',
#  'ShipTo',
#  'source_sheet',
#  'Type',
#  'sub_cat',
#  'exchange_rate_to_usd',
#  'usd_adjusted_price',
#  'usd_adjusted_total',
#  'Year',
#  'Capacity',
#  'Unit',
#  'total_cap']

# %%
df_cleaned.describe(include='all')
# Out:
#                   PI Customer      ItemCode              Product Currency  \
# count   2.057050e+05   205708        174798               205708   205259
# unique           NaN      197          2531                 1609        6
# top              NaN       C2  13-08RKS2202  C2 Storage Advanced      EUR
# freq             NaN    30910          4820                 6660   107644
# mean    6.085973e+05      NaN           NaN                  NaN      NaN
# std     7.484590e+05      NaN           NaN                  NaN      NaN
# min     2.440700e+05      NaN           NaN                  NaN      NaN
# 25%     2.839240e+05      NaN           NaN                  NaN      NaN
# 50%     2.987940e+05      NaN           NaN                  NaN      NaN
# 75%     3.124140e+05      NaN           NaN                  NaN      NaN
# max     2.491341e+06      NaN           NaN                  NaN      NaN
#
#                Price       Quantity       Discount   T/T Discount  \
# count   2.057080e+05  205708.000000  205708.000000  205708.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    2.028878e+03      31.515469       0.009982       0.553372
# std     3.381188e+04     426.518178       0.266056       1.045254
# min     0.000000e+00       1.000000      -0.020000       0.000000
# 25%     1.082400e+02       1.000000       0.000000       0.000000
# 50%     2.640000e+02       4.000000       0.000000       0.000000
# 75%     8.357100e+02      16.000000       0.000000       1.000000
# max     1.000000e+07   67055.000000      20.000000       4.000000
#
#                Total  ... source_sheet    Type sub_cat exchange_rate_to_usd  \
# count   2.057080e+05  ...       205708  205708  205708        192355.000000
# unique           NaN  ...            4      10      61                  NaN
# top              NaN  ...         2024  SERVER   Other                  NaN
# freq             NaN  ...        91386   78389   31451                  NaN
# mean    1.776185e+04  ...          NaN     NaN     NaN             1.024808
# std     1.118395e+05  ...          NaN     NaN     NaN             0.045569
# min     0.000000e+00  ...          NaN     NaN     NaN             0.006700
# 25%     3.680000e+02  ...          NaN     NaN     NaN             1.000000
# 50%     1.867205e+03  ...          NaN     NaN     NaN             1.050000
# 75%     6.184250e+03  ...          NaN     NaN     NaN             1.050000
# max     1.000000e+07  ...          NaN     NaN     NaN             1.050000
#
#        usd_adjusted_price usd_adjusted_total           Year      Capacity  \
# count        1.923550e+05       1.923550e+05  205708.000000  30794.000000
# unique                NaN                NaN            NaN           NaN
# top                   NaN                NaN            NaN           NaN
# freq                  NaN                NaN            NaN           NaN
# mean         8.290111e+02       6.992862e+03    2023.520515   7010.469377
# std          7.327454e+03       2.552006e+04       0.499580   5969.055162
# min          1.000000e-02       1.000000e-01    2023.000000      2.000000
# 25%          1.026900e+02       3.200303e+02    2023.000000    960.000000
# 50%          2.575965e+02       1.689208e+03    2024.000000   6000.000000
# 75%          6.176520e+02       5.320000e+03    2024.000000  12000.000000
# max          1.461371e+06       1.461371e+06    2024.000000  20000.000000
#
#          Unit     total_cap
# count   30794  2.057080e+05
# unique      1           NaN
# top        GB           NaN
# freq    30794           NaN
# mean      NaN  5.641448e+04
# std       NaN  4.546944e+05
# min       NaN  0.000000e+00
# 25%       NaN  0.000000e+00
# 50%       NaN  0.000000e+00
# 75%       NaN  0.000000e+00
# max       NaN  3.636000e+07
#
# [11 rows x 27 columns]

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205708 entries, 0 to 205707
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   PI                    205705 non-null  float64
#  1   Customer              205708 non-null  object
#  2   ItemCode              174798 non-null  object
#  3   Product               205708 non-null  object
#  4   Currency              205259 non-null  object
#  5   Price                 205708 non-null  float64
#  6   Quantity              205708 non-null  int64
#  7   Discount              205708 non-null  float64
#  8   T/T Discount          205708 non-null  float64
#  9   Total                 205708 non-null  float64
#  10  ShipDate              205708 non-null  object
#  11  InvDate               205708 non-null  object
#  12  DeliveryFrom          205708 non-null  object
#  13  Destination           205657 non-null  object
#  14  Comments              5156 non-null    object
#  15  Country               205660 non-null  object
#  16  ShipTo                174038 non-null  object
#  17  source_sheet          205708 non-null  object
#  18  Type                  205708 non-null  object
#  19  sub_cat               205708 non-null  object
#  20  exchange_rate_to_usd  192355 non-null  float64
#  21  usd_adjusted_price    192355 non-null  float64
#  22  usd_adjusted_total    192355 non-null  float64
#  23  Year                  205708 non-null  int32
#  24  Capacity              30794 non-null   float64
#  25  Unit                  30794 non-null   object
#  26  total_cap             205708 non-null  int64
# dtypes: float64(9), int32(1), int64(2), object(15)
# memory usage: 41.6+ MB
